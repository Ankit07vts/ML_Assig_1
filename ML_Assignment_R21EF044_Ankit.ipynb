# %%
import numpy as np
import pandas as pd
import seaborn as sns
sns.set_palette('husl')
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import GaussianNB



data = pd.read_csv('Iris.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
data['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
data.isin(["?"]).sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
data.drop("Id",axis=1)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
tmp = data.drop('Id', axis=1)
g = sns.pairplot(tmp, hue='Species', markers='+')
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
g = sns.violinplot(y='Species', x='SepalLengthCm', data=data, inner='quartile')
plt.show()

# %%
g = sns.violinplot(y='Species', x='SepalWidthCm', data=data, inner='quartile')
plt.show()

# %%
g = sns.violinplot(y='Species', x='PetalLengthCm', data=data, inner='quartile')
plt.show()

# %%
g = sns.violinplot(y='Species', x='PetalWidthCm', data=data, inner='quartile')
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.plot(data['SepalLengthCm'])
plt.ylabel('SepalLengthCm')
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.plot(data['SepalWidthCm'])
plt.ylabel('SepalWidthCm')
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.plot(data['PetalLengthCm'])
plt.ylabel('PetalLengthCm')
plt.show()

# %%
plt.figure(figsize=(15, 5))
plt.plot(data['PetalWidthCm'])
plt.ylabel('PetalWidthCm')
plt.show()

# %%
categories = data['PetalLengthCm']
counts = data['PetalWidthCm']
plt.figure(figsize=(6, 6))  
plt.pie(counts, labels=categories, autopct='%1.1f%%', startangle=90)
plt.show()

# %%
sns.boxplot(x=data["PetalLengthCm"])
# Out:
# <Axes: xlabel='PetalLengthCm'>

# %%
sns.boxplot(x=data["PetalWidthCm"])
# Out:
# <Axes: xlabel='PetalWidthCm'>

# %%
sns.boxplot(x=data["SepalLengthCm"])
# Out:
# <Axes: xlabel='SepalLengthCm'>

# %%
sns.boxplot(x=data["SepalWidthCm"])
# Out:
# <Axes: xlabel='SepalWidthCm'>

# %%
sns.histplot(data[data['Species']=='Iris-setosa']['SepalWidthCm'],color='green')
sns.histplot(data[data['Species']=='Iris-virginica']['SepalWidthCm'],color='blue')
sns.histplot(data[data['Species']=='Iris-versicolor']['SepalWidthCm'],color='red')
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
sns.histplot(data[data['Species']=='Iris-setosa']['SepalLengthCm'],color='green')
sns.histplot(data[data['Species']=='Iris-virginica']['SepalLengthCm'],color='blue')
sns.histplot(data[data['Species']=='Iris-versicolor']['SepalLengthCm'],color='red')
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
sns.histplot(data[data['Species']=='Iris-setosa']['PetalWidthCm'],color='green')
sns.histplot(data[data['Species']=='Iris-virginica']['PetalWidthCm'],color='blue')
sns.histplot(data[data['Species']=='Iris-versicolor']['PetalWidthCm'],color='red')
# Out:
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
sns.histplot(data[data['Species']=='Iris-setosa']['PetalLengthCm'],color='green')
sns.histplot(data[data['Species']=='Iris-virginica']['PetalLengthCm'],color='blue')
sns.histplot(data[data['Species']=='Iris-versicolor']['PetalLengthCm'],color='red')
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
x=data.iloc[:,:-1]
x.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0   1            5.1           3.5            1.4           0.2
# 1   2            4.9           3.0            1.4           0.2
# 2   3            4.7           3.2            1.3           0.2
# 3   4            4.6           3.1            1.5           0.2
# 4   5            5.0           3.6            1.4           0.2

# %%
y=data.iloc[:,-1]
y.head()
# Out:
# 0    Iris-setosa
# 1    Iris-setosa
# 2    Iris-setosa
# 3    Iris-setosa
# 4    Iris-setosa
# Name: Species, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
y=LabelEncoder().fit_transform(y)
y=pd.DataFrame(y)
y.head()
# Out:
#    0
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %%
X = data.drop(['Id', 'Species'], axis=1)
y = data['Species']
print(X.shape)
print(y.shape)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=5)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (150, 4)
# (150,)
# (90, 4)
# (90,)
# (60, 4)
# (60,)

# %%
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.9833333333333333

# %%
knn = KNeighborsClassifier(n_neighbors=12)
knn.fit(X_train, y_train)
y_pred=knn.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.9833333333333333

# %%
dc=DecisionTreeClassifier(max_depth=5)
dc.fit(X_train,y_train)
y_pred=dc.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.95

# %%
ml=MLPClassifier(alpha=1,max_iter=1000)
ml.fit(X_train,y_train)
y_pred=ml.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.9833333333333333

# %%
gb=GaussianNB()
gb.fit(X_train,y_train)
y_pred=gb.predict(X_test)
print(metrics.accuracy_score(y_test, y_pred))
# Out:
# 0.9666666666666667
